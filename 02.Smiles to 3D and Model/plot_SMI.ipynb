# %% [markdown]
# draw *c1cccc(-c2nc3ccc(-c4ccc5[nH]c(*)nc5c4)cc3[nH]2)c1

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import  Draw
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults
m = Chem.MolFromSmiles('*c1cccc(-c2nc3ccc(-c4ccc5[nH]c(*)nc5c4)cc3[nH]2)c1')
opts =  DrawingOptions()
opts.atomLabelFontSize=400

opts.includeAtomNumbers=True
opts.dblBondLengthFrac=0.8
opts.includeAtomNumbers=True
opts.dotsPerAngstrom=1000
Draw.MolToImage(m,options=opts,size=(500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %%
def mol_with_atom_index(mol):
    for atom in mol.GetAtoms():
        atom.SetAtomMapNum(atom.GetIdx())
    return mol

smi = '*c1cccc(-c2nc3ccc(-c4ccc5[nH]c(*)nc5c4)cc3[nH]2)c1'
mol = Chem.MolFromSmiles(smi)
mol_with_atom_index(mol)

# %% [markdown]
# *c1cccc(-c2nc3ccc(-c4ccc5nc(*)nc5c4)cc3n2)c1,1,ethyl:2

# %%
smi2 = '*c1cccc(-c2nc3ccc(-c4ccc5nc(*)nc5c4)cc3n2)c1'
mol2 = Chem.MolFromSmiles(smi2)
mol_with_atom_index(mol2)
# Out:
# [15:38:51] Can't kekulize mol.  Unkekulized atoms: 6 7 8 9 10 11 22 23 24
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 smi2 = '*c1cccc(-c2nc3ccc(-c4ccc5nc(*)nc5c4)cc3n2)c1'
#       2 mol2 = Chem.MolFromSmiles(smi2)
# ----> 3 mol_with_atom_index(mol2)
#
# Cell In[13], line 2, in mol_with_atom_index(mol)
#       1 def mol_with_atom_index(mol):
# ----> 2     for atom in mol.GetAtoms():
#       3         atom.SetAtomMapNum(atom.GetIdx())
#       4     return mol
#
# AttributeError: 'NoneType' object has no attribute 'GetAtoms'

# %%
smi = '*c1cccc(-c2nc3ccc(-c4ccc5[nH]c(*)nc5c4)cc3[nH]2)c1'
mol = Chem.MolFromSmiles(smi)
mol_with_atom_index(mol)

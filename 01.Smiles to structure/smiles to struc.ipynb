# %% [markdown]
# # small

# %%
from rdkit import Chem
from rdkit.Chem import Draw
 
smiles = "CCO"
mol = Chem.MolFromSmiles(smiles)
img = Draw.MolsToGridImage([mol], molsPerRow=1, subImgSize=(256, 256),)
img
# img.save("data//1.png")

# %% [markdown]
# # first

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# List of SMILES strings for your molecules
smiles_list = [
    "*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1C(C)(OC)OC(=O)c1ccc(C(C)(C)C#N)cc1",
    "*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1C(C)(OC)OC(=O)c1c(C)c(-c2ccc([N+](=O)[O-])cc2)n1",
    "*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1C(C)(OC)OC(=O)c1c(C)c(-c2cc(Br)c([N+](=O)[O-])cc2)c1",
    "*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1CC(C)(C)C",
    "*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1C(C)(OC)OC(=O)c1c(C)c(C)c(NC(=O)c2ccccc2)cc1"
]

# Convert SMILES strings to RDKit molecule objects
mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]

# Create legends for each molecule
legends = [f'Molecule {i+1}' for i in range(len(smiles_list))]

# Generate and display the grid image of molecules with legends
img = Draw.MolsToGridImage(mols, molsPerRow=5, subImgSize=(300, 300), legends=legends)
img

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# List of SMILES strings for your molecules
smiles_list = [
    "*c1cccc(-c2nc3cc(-c4ccc5[nH]c(*)nc5c4)ccc3s2)c1",
    "*C(=O)c1cc2c(cc1Cl)C(=O)N(c1cc(C(=O)O)cc(N3C(=O)c4cc(*)c(Cl)cc4C3=O)c1)C2=O",
    "*c1ccc(N2C(=O)c3ccc(-c4cccc5c4C(=O)N(*)C5=O)cc3C2=O)cc1",
    "*c1cccc(-c2nc3cc(-c4ccc5[nH]c(*)nc5c4)ccc3[nH]2)c1",
    "*c1cccc(-c2nc3ccc(-c4ccc5[nH]c(*)nc5c4)cc3[nH]2)c1"
]

# Convert SMILES strings to RDKit molecule objects
mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]

# Create legends for each molecule
legends = [f'Molecule {i+6}' for i in range(len(smiles_list))]  # Starting from 6 since these are molecules 6-10

# Generate and display the grid image of molecules with legends
img = Draw.MolsToGridImage(mols, molsPerRow=5, subImgSize=(300, 300), legends=legends)
img

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# List of SMILES strings for your molecules
smiles_list = [
    "*c1ccc(C(=O)Nc2ccc(C(=O)Nc3ccc(NC(=O)c4ccc(N5C(=O)c6ccc(C(*)(C(F)(F)F)C(F)(F)F)cc6C5=O)cc4)cc3)cc2)cc1",
    "*/c1ccc2c(c1)C(=O)N(c1ccc(C(=O)Nc3ccc(NC(=O)c4ccc(C(=O)Nc5ccc(N6C(=O)c7ccc(C(*)(C(F)(F)F)C(F)(F)F)cc7C6=O)cc5)cc4)cc3)cc1)C2=O",
    "*/c1ccc(N2C(=O)c3ccc(-c4ccc5c(c4)C(=O)N(*)C5=O)cc3C2=O)cc1",
    "*c1ccc(C(=O)Nc2ccc(NC(=O)c3ccc(N4C(=O)c5ccc(C(*)(C(F)(F)F)C(F)(F)F)cc5C4=O)cc3)cc2)cc1",
    "*c1ccc2c(c1)C(=O)N(c1ccc(NC(=O)c3ccc(C(=O)Nc4ccc(N5C(=O)c6ccc(C(*)(C(F)(F)F)C(F)(F)F)cc6C5=O)cc4)cc3)cc1)C2=O"
]

# Convert SMILES strings to RDKit molecule objects
mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]

# Create legends for each molecule
legends = [f'Molecule {i+11}' for i in range(len(smiles_list))]  # Starting from 11 since these are molecules 11-15

# Generate and display the grid image of molecules with legends
img = Draw.MolsToGridImage(mols, molsPerRow=5, subImgSize=(300, 300), legends=legends)
img

# %% [markdown]
# # all in one

# %%
with open(file_path, 'r') as file:
    smiles_list = file.read().splitlines()
print(len(smiles_list))  # Check the number of SMILES strings read
# Out:
# 15

# %%
from rdkit import Chem
from rdkit.Chem import Draw

file_path = 'smiles.txt'
with open(file_path, 'r') as file:
    smiles_list = file.read().splitlines()

mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]

legends = ['CharRNN {}'.format(i+1) for i in range(5)] + \
          ['GraphINVENT {}'.format(i+1) for i in range(5, 10)] + \
          ['REINVENT {}'.format(i+1) for i in range(10, 15)]

img = Draw.MolsToGridImage(mols, molsPerRow=5, subImgSize=(200, 200), \
                           legends=legends,useSVG=True)
img
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from rdkit import Chem
#       2 from rdkit.Chem import Draw
#       4 file_path = 'smiles.txt'
#
# ModuleNotFoundError: No module named 'rdkit'

# %% [markdown]
# ## High resolution

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from IPython.display import SVG


smiles = 'C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O)O' 
m = Chem.MolFromSmiles(smiles)

def moltosvg(mol, molSize = (300,300), kekulize = True):
    mc = Chem.Mol(mol.ToBinary())
    if kekulize:
        try:
            Chem.Kekulize(mc)
        except:
            mc = Chem.Mol(mol.ToBinary())
    if not mc.GetNumConformers():
        rdDepictor.Compute2DCoords(mc)
    drawer = rdMolDraw2D.MolDraw2DSVG(molSize[0],molSize[1])
    drawer.DrawMolecule(mc)
    drawer.FinishDrawing()
    svg = drawer.GetDrawingText()
    return svg.replace('svg:','')

SVG(moltosvg(m))

# %% [markdown]
# # rp vis

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from IPython.display import SVG


smiles = '*C(=O)Nc1ccc(-c2ccc(NC(=O)c3ccc4c(c3)C(=O)N(c3ccc(Oc5ccc(N6C(=O)c7ccc(*)cc7C6=O)c(F)c5)cc3)C4=O)c(-c3ccccc3)c2F)cc1OOc1ccc(NC(=O)c2ccc(N(C)c3ccccc3C(C)(C)NC(=O)O[S-](C#N)(C(F)(F)F)C(F)(F)C#C)cc2)cc1C(C)(OC)OC(=O)c1ccc(C(C)(C)C#N)cc1' 
m = Chem.MolFromSmiles(smiles)

def moltosvg(mol, molSize = (1800,1800), kekulize = True):
    mc = Chem.Mol(mol.ToBinary())
    if kekulize:
        try:
            Chem.Kekulize(mc)
        except:
            mc = Chem.Mol(mol.ToBinary())
    if not mc.GetNumConformers():
        rdDepictor.Compute2DCoords(mc)
    drawer = rdMolDraw2D.MolDraw2DSVG(molSize[0],molSize[1])
    drawer.DrawMolecule(mc)
    drawer.FinishDrawing()
    svg = drawer.GetDrawingText()
    return svg.replace('svg:','')

SVG(moltosvg(m))
